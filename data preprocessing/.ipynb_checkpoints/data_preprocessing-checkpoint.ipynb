# %%
import pandas as pd
import numpy as np
print('successful')
# Out:
# successful

# %%
from pymongo import MongoClient

MONGO_URI = "mongodb+srv://myself28072004:jLsamTcd09jhgx21@cluster0.2vo3mcw.mongodb.net/<dbname>?retryWrites=true&w=majority"

client = MongoClient(MONGO_URI, tls=True, tlsAllowInvalidCertificates=True)
db = client["ecommerce_db"]                 
collection = db["sales"]

# %%
documents = list(collection.find())
df= pd.DataFrame(documents)

# %%
df= pd.read_csv('raw_data.csv')

# %%
df.to_csv("raw_data.csv")

# %%
df.head(5)
# Out:
#    Unnamed: 0                       _id  TransactionID  CustomerID  ProductID  \
# 0           0  68f24604b498e3d7cc23dbf6              9        6578        948
# 1           1  68f24604b498e3d7cc23dbfe             17        7420        868
# 2           2  68f24604b498e3d7cc23dc22             53        4073        116
# 3           3  68f24604b498e3d7cc23dc25             56        8989        603
# 4           4  68f24604b498e3d7cc23dc31             68        8916        368
#
#   ProductCategory  Quantity   Price  Discount      TransactionDate  \
# 0           Books         4  202.66      0.12  2024-08-04T17:13:39
# 1          Beauty         4  218.68      0.19  2024-07-24T08:49:00
# 2            Toys         2  668.62      0.17  2023-10-11T11:19:27
# 3            Toys         2  960.25      0.26  2024-09-01T20:50:48
# 4        Clothing         1  999.96      0.12  2024-01-27T21:47:54
#
#       PaymentMethod   CustomerLocation  CustomerAge CustomerGender  \
# 0  Cash on Delivery    Port Philipberg           37           Male
# 1       Credit Card         Marioburgh           21          Other
# 2        Debit Card        Morganmouth           36          Other
# 3            PayPal       Adrienneberg           66         Female
# 4        Debit Card  East Courtneyview           66         Female
#
#   CustomerIncomeGroup  CustomerLoyaltyScore
# 0                 Low                 28.61
# 1              Medium                  9.93
# 2                 Low                 61.61
# 3                 Low                 35.51
# 4                 Low                 38.61

# %%
# df['Unnamed: 0']
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 15 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   _id                   100000 non-null  object
#  1   TransactionID         100000 non-null  int64
#  2   CustomerID            100000 non-null  int64
#  3   ProductID             100000 non-null  int64
#  4   ProductCategory       100000 non-null  object
#  5   Quantity              100000 non-null  int64
#  6   Price                 100000 non-null  float64
#  7   Discount              100000 non-null  float64
#  8   TransactionDate       100000 non-null  object
#  9   PaymentMethod         100000 non-null  object
#  10  CustomerLocation      100000 non-null  object
#  11  CustomerAge           100000 non-null  int64
#  12  CustomerGender        100000 non-null  object
#  13  CustomerIncomeGroup   100000 non-null  object
#  14  CustomerLoyaltyScore  100000 non-null  float64
# dtypes: float64(3), int64(5), object(7)
# memory usage: 11.4+ MB

# %%
categ_variable= df.iloc[:, [4,9,10,12,13]]
for col in categ_variable.columns:
    print(categ_variable[col].value_counts(), "\n")
# Out:
# ProductCategory
# Clothing          14363
# Books             14342
# Toys              14304
# Home & Kitchen    14295
# Beauty            14277
# Electronics       14221
# Sports            14198
# Name: count, dtype: int64
#
# PaymentMethod
# Bank Transfer       20227
# Debit Card          19978
# Credit Card         19957
# PayPal              19937
# Cash on Delivery    19901
# Name: count, dtype: int64
#
# CustomerLocation
# New Michael          100
# Lake Michael          94
# East Michael          83
# South Michael         82
# North Michael         82
#                     ...
# Port Isaiahbury        1
# North Arielfurt        1
# South Patrickbury      1
# Ewingfurt              1
# South Joelburgh        1
# Name: count, Length: 38283, dtype: int64
#
# CustomerGender
# Male      33604
# Other     33343
# Female    33053
# Name: count, dtype: int64
#
# CustomerIncomeGroup
# Medium    33428
# Low       33328
# High      33244
# Name: count, dtype: int64

# %%
num_variables= df.iloc[:, [1,2,3,5,6,7,11,14]]
num_variables.describe()
# Out:
#        TransactionID     CustomerID      ProductID       Quantity  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean    50000.500000    5504.000280     550.554140       2.499750
# std     28867.657797    2600.472561     260.256267       1.118353
# min         1.000000    1000.000000     100.000000       1.000000
# 25%     25000.750000    3251.000000     325.000000       1.000000
# 50%     50000.500000    5511.000000     552.000000       3.000000
# 75%     75000.250000    7751.000000     777.000000       3.000000
# max    100000.000000    9999.000000     999.000000       4.000000
#
#                Price       Discount    CustomerAge  CustomerLoyaltyScore
# count  100000.000000  100000.000000  100000.000000         100000.000000
# mean      501.469993       0.149962      43.381210             50.004314
# std       287.536905       0.086638      15.030994             28.888185
# min         5.010000       0.000000      18.000000              0.000000
# 25%       251.537500       0.070000      30.000000             24.920000
# 50%       501.580000       0.150000      43.000000             49.920000
# 75%       750.397500       0.220000      56.000000             75.070000
# max      1000.000000       0.300000      69.000000            100.000000

# %%
import matplotlib.pyplot as plt

# %%
plt.boxplot(num_variables['Quantity'])

# %%
plt.boxplot(num_variables['Price'])

# %%
plt.boxplot(num_variables['Discount'])

# %%
plt.boxplot(num_variables['CustomerAge'])

# %%
plt.boxplot(num_variables['CustomerLoyaltyScore'])

# %%
conda install scikit-learn

# %%
categorical_cols = ['ProductCategory', 'PaymentMethod', 'CustomerGender']
df_encoded = pd.get_dummies(df, columns=categorical_cols)
dummy_cols = [col for col in df_encoded.columns if any(c in col for c in categorical_cols)]
df_encoded[dummy_cols] = df_encoded[dummy_cols].astype(int)

# %%
df.head(10)
# Out:
#                         _id  TransactionID  CustomerID  ProductID  \
# 0  68f24604b498e3d7cc23dbf6              9        6578        948
# 1  68f24604b498e3d7cc23dbfe             17        7420        868
# 2  68f24604b498e3d7cc23dc22             53        4073        116
# 3  68f24604b498e3d7cc23dc25             56        8989        603
# 4  68f24604b498e3d7cc23dc31             68        8916        368
# 5  68f24604b498e3d7cc23dc38             75        9684        148
# 6  68f24604b498e3d7cc23dc3f             82        6463        599
# 7  68f24604b498e3d7cc23dc54            103        4840        723
# 8  68f24604b498e3d7cc23dc67            122        7019        802
# 9  68f24604b498e3d7cc23dc68            123        2757        750
#
#   ProductCategory  Quantity   Price  Discount      TransactionDate  \
# 0           Books         4  202.66      0.12  2024-08-04T17:13:39
# 1          Beauty         4  218.68      0.19  2024-07-24T08:49:00
# 2            Toys         2  668.62      0.17  2023-10-11T11:19:27
# 3            Toys         2  960.25      0.26  2024-09-01T20:50:48
# 4        Clothing         1  999.96      0.12  2024-01-27T21:47:54
# 5           Books         3  414.37      0.25  2024-08-25T18:27:53
# 6          Beauty         3  885.53      0.05  2023-09-24T18:59:42
# 7           Books         2   13.41      0.12  2024-06-09T08:35:25
# 8          Sports         3  570.82      0.01  2024-03-13T08:07:18
# 9           Books         3  300.88      0.19  2024-07-04T22:33:32
#
#       PaymentMethod   CustomerLocation  CustomerAge CustomerGender  \
# 0  Cash on Delivery    Port Philipberg           37           Male
# 1       Credit Card         Marioburgh           21          Other
# 2        Debit Card        Morganmouth           36          Other
# 3            PayPal       Adrienneberg           66         Female
# 4        Debit Card  East Courtneyview           66         Female
# 5     Bank Transfer      Hernandezside           34          Other
# 6     Bank Transfer         Joshuafurt           57         Female
# 7       Credit Card        Summersstad           18           Male
# 8     Bank Transfer       Mathewsshire           58          Other
# 9     Bank Transfer        New Kaitlyn           18         Female
#
#   CustomerIncomeGroup  CustomerLoyaltyScore
# 0                 Low                 28.61
# 1              Medium                  9.93
# 2                 Low                 61.61
# 3                 Low                 35.51
# 4                 Low                 38.61
# 5                High                 15.31
# 6              Medium                 99.74
# 7                High                 79.02
# 8              Medium                  4.46
# 9                High                 89.35

# %%
df_encoded.head()
# Out:
#    Unnamed: 0                       _id  TransactionID  CustomerID  ProductID  \
# 0           0  68f24604b498e3d7cc23dbf6              9        6578        948
# 1           1  68f24604b498e3d7cc23dbfe             17        7420        868
# 2           2  68f24604b498e3d7cc23dc22             53        4073        116
# 3           3  68f24604b498e3d7cc23dc25             56        8989        603
# 4           4  68f24604b498e3d7cc23dc31             68        8916        368
#
#    Quantity   Price  Discount      TransactionDate   CustomerLocation  ...  \
# 0         4  202.66      0.12  2024-08-04T17:13:39    Port Philipberg  ...
# 1         4  218.68      0.19  2024-07-24T08:49:00         Marioburgh  ...
# 2         2  668.62      0.17  2023-10-11T11:19:27        Morganmouth  ...
# 3         2  960.25      0.26  2024-09-01T20:50:48       Adrienneberg  ...
# 4         1  999.96      0.12  2024-01-27T21:47:54  East Courtneyview  ...
#
#    ProductCategory_Sports ProductCategory_Toys  PaymentMethod_Bank Transfer  \
# 0                       0                    0                            0
# 1                       0                    0                            0
# 2                       0                    1                            0
# 3                       0                    1                            0
# 4                       0                    0                            0
#
#    PaymentMethod_Cash on Delivery  PaymentMethod_Credit Card  \
# 0                               1                          0
# 1                               0                          1
# 2                               0                          0
# 3                               0                          0
# 4                               0                          0
#
#    PaymentMethod_Debit Card  PaymentMethod_PayPal  CustomerGender_Female  \
# 0                         0                     0                      0
# 1                         0                     0                      0
# 2                         1                     0                      0
# 3                         0                     1                      1
# 4                         1                     0                      1
#
#    CustomerGender_Male  CustomerGender_Other
# 0                    1                     0
# 1                    0                     1
# 2                    0                     1
# 3                    0                     0
# 4                    0                     0
#
# [5 rows x 28 columns]

# %%
from sklearn.preprocessing import OrdinalEncoder
encoder = OrdinalEncoder(categories=[['Low', 'Medium', 'High']])
encoded = encoder.fit_transform(df_encoded[['CustomerIncomeGroup']])
df_encoded['CustomerIncomeGroup']= encoded.astype('int')

# %%
df_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 27 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   _id                             100000 non-null  object
#  1   TransactionID                   100000 non-null  int64
#  2   CustomerID                      100000 non-null  int64
#  3   ProductID                       100000 non-null  int64
#  4   Quantity                        100000 non-null  int64
#  5   Price                           100000 non-null  float64
#  6   Discount                        100000 non-null  float64
#  7   TransactionDate                 100000 non-null  object
#  8   CustomerLocation                100000 non-null  object
#  9   CustomerAge                     100000 non-null  int64
#  10  CustomerIncomeGroup             100000 non-null  int64
#  11  CustomerLoyaltyScore            100000 non-null  float64
#  12  ProductCategory_Beauty          100000 non-null  int64
#  13  ProductCategory_Books           100000 non-null  int64
#  14  ProductCategory_Clothing        100000 non-null  int64
#  15  ProductCategory_Electronics     100000 non-null  int64
#  16  ProductCategory_Home & Kitchen  100000 non-null  int64
#  17  ProductCategory_Sports          100000 non-null  int64
#  18  ProductCategory_Toys            100000 non-null  int64
#  19  PaymentMethod_Bank Transfer     100000 non-null  int64
#  20  PaymentMethod_Cash on Delivery  100000 non-null  int64
#  21  PaymentMethod_Credit Card       100000 non-null  int64
#  22  PaymentMethod_Debit Card        100000 non-null  int64
#  23  PaymentMethod_PayPal            100000 non-null  int64
#  24  CustomerGender_Female           100000 non-null  int64
#  25  CustomerGender_Male             100000 non-null  int64
#  26  CustomerGender_Other            100000 non-null  int64
# dtypes: float64(3), int64(21), object(3)
# memory usage: 20.6+ MB

# %%
df_encoded['CustomerIncomeGroup'].value_counts()
# Out:
# CustomerIncomeGroup
# 1    33428
# 0    33328
# 2    33244
# Name: count, dtype: int64
